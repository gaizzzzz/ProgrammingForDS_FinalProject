# %% [markdown]
# <div style="text-align: center; background-color: #559cff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Lab 02 - Introduction To Data Science @ FIT-HCMUS, VNU-HCM 📌
# </div>

# %% [markdown]
# <div style="text-align: center; background-color: #b1d1ff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Stage 3.0 - Exploratory data analysis
# </div>

# %% [markdown]
# ## Import

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# YOUR CODE HERE (OPTION) 
# If you need other libraries, you can import them here
import matplotlib as mpl
import seaborn as sns

# %% [markdown]
# ## Exploring your data

# %% [markdown]
# ### Read cleaned data from file (0.25 points)

# %% [markdown]
# We can now use the cleaned dataset for analysis. Thus, we first read the CSV files we created in the previous pre-processing task.

# %%
# YOUR CODE HERE
cleaned_df = pd.read_csv('../data/processed/21120169_europe_processed.csv')
#raise NotImplementedError()

# %%
# TEST
cleaned_df.head()
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0         2775634.0          1391086.0        1384548.0   10.813117
# 1         2811666.0          1407212.0        1404454.0   10.240000
# 2         2837849.0          1418585.0        1419264.0   10.285000
# 3         2854191.0          1425363.0        1428828.0   10.343000
# 4         2866376.0          1430495.0        1435881.0   10.517000
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0   10.096538                        9.0                  26.361868
# 1   11.325000                        9.0                  21.562780
# 2   10.785000                        9.0                  20.781540
# 3    8.480000                        9.0                  20.150670
# 4    8.308000                        9.0                  19.745660
#
#    Employment in Agriculture(%)  Female Employment in Agriculture(%)  \
# 0                      9.386339                             8.456056
# ...

# %%
# TEST
cleaned_df.shape
# Out:
# (1120, 25)

# %% [markdown]
# ### Numerical analysis using descriptive statistics (0.25 points)

# %% [markdown]
# Descriptive statistics show the characteristics of numerical features. It shows us the information such as:
# - The mean (and you can go further with advanced techiques as Arithmetic mean, Geometric mean, Harmonic mean)
# - The median
# - The mode
# - Quantiles (Quartiles, Percentiles, Deciles, Crocodiles?)
# - Range and IQR (Interquartile Range) (you might find that its relation to box plots)
# - Variance and Standard deviation (std dev)
# - Coefficient of Variation
# - Skewness
# - Kurtosis
# - Standard Error (of the sample mean)
# - Moments
# - Covariance and Correlation
#
# Due the scope of this lab, you just need to use basic function of Pandas to calculate basic descriptive statistics information and give insights from it.

# %%
df_copy = cleaned_df.drop(['Year', 'Country'], axis='columns')

# YOUR CODE HERE
df_copy.describe()
#raise NotImplementedError()
# Out:
#        Total Population  Female Population  Male Population   Birth Rate  \
# count      1.120000e+03       1.120000e+03     1.120000e+03  1120.000000
# mean       1.399210e+07       7.200463e+06     6.791642e+06    10.813117
# std        2.085705e+07       1.072965e+07     1.013146e+07     1.913733
# min        2.488600e+04       1.277900e+04     1.210700e+04     5.900000
# 25%        2.019648e+06       1.025421e+06     9.939572e+05     9.500000
# 50%        5.376422e+06       2.743866e+06     2.625598e+06    10.699000
# 75%        1.053030e+07       5.424500e+06     5.169164e+06    11.700000
# max        8.407981e+07       4.259320e+07     4.148661e+07    25.000000
#
#         Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# count  1120.000000                1120.000000                1120.000000
# mean     10.096538                  10.231975                  26.361868
# std       2.409081                   1.272694                   6.026379
# ...

# %% [markdown]
# **TODO**: Give your obervation here
# \
# According to the above descriptive statistics, we can see the value of `count` row always equals to `1120`.

# %% [markdown]
# ### Describe the correlation between features in the dataset (0.75 points)

# %% [markdown]
# Considering the available features within the training dataset, we want to identify and analyse the relationships between them, and then determine which features within the dataset significantly contribute to our solution goal. By using calculation and visualisation, Python allows us to create a correlation matrix, which is a table that represents the correlation coefficients between different variables.

# %% [markdown]
# Now let's make a correlation matrix, then visualize it, and describe what insights you observed?

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION) 
df_copy = cleaned_df.copy()
df_copy['Year'] = df_copy['Year'].astype('category').cat.codes
df_copy['Country'] = df_copy['Country'].astype('category').cat.codes

# %%
# YOUR CODE HERE
corr_matrix = df_copy.drop(columns = ['Year', 'Country']).corr()

sns.set(rc = {'figure.figsize' : (20, 10)})
sns.heatmap(corr_matrix, annot = True, fmt = '.2g', cmap = 'coolwarm')
plt.show()
#raise NotImplementedError()

# %% [markdown]
# **Question 01**: How does the correlation between features change in the top 10 countries with the LARGEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the country population is large.

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)
df_copy = cleaned_df.loc[cleaned_df['Year'] == 2022]
largest_pop_country = (df_copy.set_index('Country').nlargest(10, 'Total Population').index).tolist()

largest_pop_df = df_copy.loc[df_copy['Country'].isin(largest_pop_country)]

# %%
corr_matrix = largest_pop_df.drop(columns = ['Year', 'Country']).corr()

sns.set(rc = {'figure.figsize' : (20, 10)})
sns.heatmap(corr_matrix, annot = True, fmt = '.2g', cmap = 'coolwarm')
plt.show()

# %% [markdown]
# **YOUR ANSWER**
# \
# The correlation of the top 10 countries with the largest population has changed, more positive correlations have appeared.
# It follows that having a large population makes its parameters more variable and related to each other in energy comsumption features. Besides, the relationship of `Life Expectancy` and `Employment` has more negative correlations.

# %% [markdown]
# **Question 02**: How does the correlation between features change in the top 10 countries with the SMALLEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the conutry population is small.

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION) 
df_copy = cleaned_df.loc[cleaned_df['Year'] == 2022]
smallest_pop_country = (df_copy.set_index('Country').nsmallest(10, 'Total Population').index).tolist()

smallest_pop_df = df_copy.loc[df_copy['Country'].isin(smallest_pop_country)]

# %%
# YOUR CODE HERE
corr_matrix = smallest_pop_df.drop(columns = ['Year', 'Country']).corr()

sns.set(rc = {'figure.figsize' : (20, 10)})
sns.heatmap(corr_matrix, annot = True, fmt = '.2g', cmap = 'coolwarm')
plt.show()

# %% [markdown]
# **YOUR ANSWER**
# \
# Similar to the above correlation, the correlation of the top 10 countries with the smallest population has changed. The employment features have more positive correlations such as `Employment in Industry`, `Employment in Agriculture`, etc.
# \
# Question: Is that possible to drop any features that have less effect?
# According to the above correlations, I think we should not drop any features that have less effect, because they might have something useful in some cases.

# %% [markdown]
# ## Making a question? (1.25 points)

# %% [markdown]
# After exploring the data, we have a better understanding of the data. Now let's see what questions can be answered with this data.
#
# **A possible question is:** What is the population situation of the countries on the continent today?
#
# **Answering this question will** help us to see the current population status and predictions about the future development of the labor force of the countries on the continent are under consideration.
#
# **How we answer this question**: we will consider the Average Birth Rate and Death Rate for countries across all the year.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# Step 01: construct Average Birth Rate dataframe for each country.

# %%
# Create a new dataframe
avg_birthrate_df = pd.DataFrame()

# YOUR CODE HERE
avg_birthrate_df = cleaned_df[['Birth Rate', 'Country']].groupby('Country').apply(lambda df_: df_.mean())
#raise NotImplementedError()

# %%
# You can just construct plotting for top countries
# YOUR CODE HERE
top10_avg_birthrate_df = avg_birthrate_df.nlargest(10, 'Birth Rate')
labels = (top10_avg_birthrate_df.index).tolist()
values = top10_avg_birthrate_df['Birth Rate'].tolist()

plt.bar(labels, values, color = 'maroon', width = 0.4)
plt.xlabel('Countries')
plt.ylabel('Birth Rate')
plt.title('Top 10 Countries with The Highest Birthrate')
plt.show()
#raise NotImplementedError()

# %% [markdown]
# Step 02: construct Average Death Rate dataframe for each country.

# %%
# Create a new dataframe
avg_deathrate_df = pd.DataFrame()

# YOUR CODE HERE
avg_deathrate_df = cleaned_df[['Death Rate', 'Country']].groupby('Country').apply(lambda df_: df_.mean())
#raise NotImplementedError()

# %%
# You can just construct plotting for top countries
# YOUR CODE HERE
top10_avg_deathrate_df = avg_deathrate_df.nlargest(10, 'Death Rate')
labels = (top10_avg_deathrate_df.index).tolist()
values = top10_avg_deathrate_df['Death Rate'].tolist()

plt.bar(labels, values, color = 'maroon', width = 0.4)
plt.xlabel('Countries')
plt.ylabel('Death Rate')
plt.title('Top 10 Countries with The Highest Deathrate')
plt.show()
#raise NotImplementedError()

# %% [markdown]
# **TODO**: Give your obervation here
# \
# Countries such as Ireland, Iceland, France have a high birthrate and a low deathrate. Therefore, their labor force will increase in the future.
# \
# Meanwhile, countries such as Germany, Bulgaria, Ukraine have a deathrate much higher than birthrate. As a result, in the future, they will encounter with the unemployment problem.

# %% [markdown]
# ## Making your own question 01? (1.5 points)

# %% [markdown]
# **YOUR ANSWER HERE**
#
# **Question**: How does the gender ratio affect the economy?\
# **Answering this question will** help us to see the economic benefits of gender equality.\
# **How we answer this question**: we will consider the average gender ratio for countries across all the year, then get the average GDP in USD of countries to compare by using gender ratio.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION) 
pop_gdp_df = pd.DataFrame()
pop_gdp_df['Country'] = cleaned_df['Country']
pop_gdp_df['Gender Ratio'] = [cleaned_df['Female Population'][i] / cleaned_df['Male Population'][i]
                              for i in range(len(cleaned_df['Male Population']))]
pop_gdp_df['GDP in USD'] = cleaned_df['GDP in USD']

avg_pop_gdp_df = pop_gdp_df[['Gender Ratio', 'GDP in USD', 'Country']].groupby('Country').apply(lambda df_: df_.mean())
avg_pop_gdp_df
# Out:
#                         Gender Ratio    GDP in USD
# Country
# Albania                     1.003333  9.737502e+09
# Austria                     1.052531  3.486680e+11
# Belarus                     1.155856  4.289820e+10
# Belgium                     1.038320  4.213568e+11
# Bosnia and Herzegovina      1.046212  1.362412e+10
# Bulgaria                    1.068450  4.272653e+10
# Croatia                     1.073084  4.750334e+10
# Czech Republic              1.042454  1.668921e+11
# Denmark                     1.017933  2.824812e+11
# Estonia                     1.139444  1.873287e+10
# Faroe Islands               0.930925  6.109808e+10
# Finland                     1.039054  2.178218e+11
# France                      1.064791  2.283673e+12
# Germany                     1.043804  3.155095e+12
# Gibraltar                   1.001599  4.140708e+11
# Greece                      1.022863  2.153745e+11
# Hungary                     1.098791  1.133599e+11
# ...

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
# plotting all countries might have a problem about X-ray, so I plot the top 20 countries with the highest GDP
top20_gdp_df = avg_pop_gdp_df.nlargest(20, 'GDP in USD')
countries = top20_gdp_df.index.tolist()

gender_ratio = top20_gdp_df['Gender Ratio']
gdp = top20_gdp_df['GDP in USD']

palette = sns.color_palette("RdBu", len(gdp))

plt.figure(figsize=[25, 15])
plt.bar(countries, gender_ratio, color = palette, width = 0.8)

plt.ylabel('Gender Ratio')
plt.ylim(0, gender_ratio.max() + 0.5)
plt.grid(True)
plt.title('How the gender ratio affect to the economy')
plt.show()

# %% [markdown]
# **MY ANSWER**
# According to the plot, we can see that most high-GDP countries have a gender ratio of almost 1.\
# This observation can be explained for some reasons:
# - The gender equality promotes the inclusivity and diversity. The work can be operated more productively.
# - It also helps to reduce the economic burden for a family that has only one economic pillar.
# - Additionally, gender equality can expand consumer markets and increase the talent pool.

# %% [markdown]
# ## Making your own question 02? (1.5 points)

# %% [markdown]
# **YOUR ANSWER HERE**
# **Question**: What is the level of renewable energy use in high-GDP countries?\
# **Answering this question will** helps us to see the level of energy use conversion of the high-GDP countries.\
# **How we answer this question**: We will get the top 5 countries with the highest average `Renewable Energy Consumption (%)`.\
# *Note*: I will remove 2 years 2021 and 2022 because rows which contain these years in the original dataset have NaN values on `Renewable Energy Consumption (%)` columns.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION) 
# REC = Renewable Energy Consumption
REC = cleaned_df[['Renewable Energy Consumption (%)', 'Year', 'Country']].set_index('Year')
REC = REC.drop([2021, 2022], axis = 'index')

avg_REC = REC[['Renewable Energy Consumption (%)', 'Country']].groupby('Country').apply(lambda df_: df_.mean()) 
top10_avg_REC = avg_REC.nlargest(10, 'Renewable Energy Consumption (%)')
top10_countries = top10_avg_REC.index.tolist()

top10_avg_REC = cleaned_df.loc[cleaned_df['Country'].isin(top10_countries)][['Renewable Energy Consumption (%)', 'Year', 'Country']]
top10_avg_REC = top10_avg_REC.set_index('Year').drop([2021, 2022], axis = 'index')
top10_avg_REC = top10_avg_REC.reset_index()
top10_avg_REC
# Out:
#      Year  Renewable Energy Consumption (%)  Country
# 0    2020                             44.58  Albania
# 1    2019                             40.11  Albania
# 2    2018                             37.83  Albania
# 3    2017                             36.94  Albania
# 4    2016                             39.44  Albania
# ..    ...                               ...      ...
# 255  1999                             34.63   Sweden
# 256  1998                             35.53   Sweden
# 257  1997                             35.51   Sweden
# 258  1996                             31.36   Sweden
# 259  1995                             33.92   Sweden
#
# [260 rows x 3 columns]

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
plt.figure(figsize=[20, 10])

for i in range(10):
    country_df = top10_avg_REC.loc[top10_avg_REC['Country'] == top10_countries[i]]
    plt.xticks(country_df['Year'], country_df['Year'])
    plt.plot(country_df['Year'], country_df['Renewable Energy Consumption (%)'], '-o', label = top10_countries[i])
    
plt.xlabel('Year')
plt.ylabel('Renewable Energy Consumption (%)')
plt.title('Renewable Energy Consumption by Years')

plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# **MY ANSWER**\
# According to the plot, we can see the conversion of using renewable energy of each country is increasing, except Albania.\
# Specially, the country with the strongest conversion is Iceland, a country with a harsh climate and the abundant natural resources of renewable energy. That's what makes Iceland one of the cleanest countries in the world.\
# In conclusion, most European countries are switching to using more renewable energy, the reason is probably to save other gas resources and protect the environment.
